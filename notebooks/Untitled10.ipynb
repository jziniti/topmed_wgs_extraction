# %%
import os
import pandas as pd
from pathlib import Path

# %%
FREEZE10 = '/proj/regeps/regep00/studies/TopMed/data/dna/whole_genome/TopMed/data/freezes/freeze.10.cdnm/'
MANIFEST_E = 'multiomics/EOCOPD/ANNOTATED_MANIFEST.csv'
MANIFEST_I = 'multiomics/GLAXO/ANNOTATED_MANIFEST.csv'
MANIFEST_P = 'multiomics/PLCOPD/ANNOTATED_MANIFEST.csv'

# %%
os.chdir(FREEZE10)

# %% [markdown]
# ----
#
# # EOCOPD

# %%
manifest = pd.read_csv(MANIFEST_E)
manifest
# Out:
#       Unnamed: 0  Unnamed: 0.1     SampleLabel  S_SAMPLEID_manifest  \
# 0              0             0       NWD100047                  NaN
# 1              1             1       NWD100794                  NaN
# 2              2             2       NWD102671                  NaN
# 3              3             3       NWD106037                  NaN
# 4              4             4       NWD106415                  NaN
# ...          ...           ...             ...                  ...
# 2230        2230          2230  ax:ST-01006044                  NaN
# 2231        2231          2231  ax:ST-01013321                  NaN
# 2232        2232          2232  ax:ST-01013322                  NaN
# 2233        2233          2233  ax:ST-01015833                  NaN
# 2234        2234          2234  ax:ST-01026292                  NaN
#
#          SampleAlias SampleTypeCode  dataset_id  is_reference  S_SUBJECTID  \
# ...

# %% [markdown]
# ----
#
# # ICGN/GLAXO

# %%
manifest_i = pd.read_csv(MANIFEST_I)
manifest_i
# Out:
#       Unnamed: 0  Unnamed: 0.1  SampleLabel  S_SAMPLEID_manifest  SampleAlias  \
# 0              0             0    NWD102259                  NaN    NWD102259
# 1              1             1    NWD105171                  NaN    NWD105171
# 2              2             2    NWD105332                  NaN    NWD105332
# 3              3             3    NWD106110                  NaN    NWD106110
# 4              4             4    NWD107349                  NaN    NWD107349
# ...          ...           ...          ...                  ...          ...
# 5866        5866          5866  ST-00024593                  NaN  ST-00024593
# 5867        5867          5867  ST-00015896                  NaN  ST-00015896
# 5868        5868          5868  ST-00015923                  NaN  ST-00015923
# 5869        5869          5869  ST-00024706                  NaN  ST-00024706
# 5870        5870          5870  ST-00024602                  NaN  ST-00024602
#
# ...

# %% [markdown]
# ----
#
# # PLCOPD

# %%
manifest_p = pd.read_csv(MANIFEST_P)
manifest_p
# Out:
#       Unnamed: 0  Unnamed: 0.1     SampleLabel  S_SAMPLEID_manifest  \
# 0              0             0       NWD106403                  NaN
# 1              1             1       NWD108770                  NaN
# 2              2             2       NWD118909                  NaN
# 3              3             3       NWD120989                  NaN
# 4              4             4       NWD127225                  NaN
# ...          ...           ...             ...                  ...
# 1489        1489          1489  ax:ST-00079992                  NaN
# 1490        1490          1490  ax:ST-00079993                  NaN
# 1491        1491          1491  ax:ST-00079994                  NaN
# 1492        1492          1492  ax:ST-00079995                  NaN
# 1493        1493          1493  ax:ST-00080113                  NaN
#
#       SampleAlias SampleTypeCode  dataset_id  is_reference  S_SUBJECTID  \
# 0       NWD106403              w           0             0  ST-00079924
# ...
