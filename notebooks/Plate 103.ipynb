# %%
import pandas as pd
import os

# %%
os.listdir('../../plate103/')
# Out:
# ['c_data.build_sample_groups',
#  'sample_groups.flag_sample_groups',
#  'ANNOTATED_MANIFEST.csv',
#  'logs',
#  'PL-01007962_v2.csv',
#  'PL-01007396_v2.csv',
#  '.snakemake',
#  'PL-01007365_v2.csv']

# %%
manifest = pd.read_csv('../../plate103/ANNOTATED_MANIFEST.csv')
manifest
# Out:
#      Unnamed: 0  Unnamed: 0.1                           SampleLabel  \
# 0            15            15                             NWD100991
# 1            16            16                             NWD866399
# 2            24            24                             NWD101684
# 3            25            25                             NWD683946
# 4           105           105                             NWD108023
# ..          ...           ...                                   ...
# 823       33016         33016  TOE867099_204078450013_R07C01_378807
# 824       33032         33032  TOE660427_204237140032_R02C01_378979
# 825       33041         33041  TOE315472_203286230158_R07C01_337681
# 826       33042         33042  TOE881059_203286230158_R06C01_337680
# 827       33043         33043  TOE859130_203991470030_R01C01_363870
#
#                             S_SAMPLEID SampleAlias SampleTypeCode  dataset_id  \
# 0               tmp/0.MANIFEST.stashq:   NWD100991              d           0
# 1               tmp/0.MANIFEST.stashq:   NWD866399              d           0
# 2               tmp/0.MANIFEST.stashq:   NWD101684              d           0
# 3               tmp/0.MANIFEST.stashq:   NWD683946              d           0
# 4               tmp/0.MANIFEST.stashq:   NWD108023              d           0
# ..                                 ...         ...            ...         ...
# 823  tmp/2.MANIFEST.stashq:S-001012078   TOE867099              m           2
# 824  tmp/2.MANIFEST.stashq:S-000561605   TOE660427              m           2
# 825  tmp/2.MANIFEST.stashq:S-001723886   TOE315472              m           2
# 826  tmp/2.MANIFEST.stashq:S-000559555   TOE881059              m           2
# 827  tmp/2.MANIFEST.stashq:S-001740177   TOE859130              m           2
#
#      is_reference  S_SUBJECTID ALIASID ExpectedGender ObservedGender  \
# 0               0  ST-00075884  12676V              F              U
# 1               0  ST-00075884  12676V              F              F
# 2               0  ST-00037405  14667E              F              M
# 3               0  ST-00037405  14667E              F              U
# 4               0  ST-01005316  22515D              F              M
# ..            ...          ...     ...            ...            ...
# 823             0  ST-01001800  21223L              F              F
# 824             0  ST-00038470  18408A              M            NaN
# 825             0  ST-00037258  18685A              F            NaN
# 826             0  ST-00037258  18685A              F            NaN
# 827             0  ST-00029860  17693U              M            NaN
#
#                                                  flags  group_id keep_drop  \
# 0    gender_mismatch;observed_gender_indeterminate;...      3528      drop
# 1                                                  NaN      3528      drop
# 2    gender_mismatch;cross_subject_match;unexpected...      8866      drop
# 3        gender_mismatch;observed_gender_indeterminate      8866      drop
# 4    gender_mismatch;cross_subject_match;unexpected...      9060      drop
# ..                                                 ...       ...       ...
# 823                                                NaN      7700    review
# 824                            observed_gender_missing      1431    review
# 825    observed_gender_missing;unexpected_geno_nomatch      1363      drop
# 826  observed_gender_missing;cross_subject_match;un...      1363      drop
# 827  observed_gender_missing;cross_subject_match;un...      1172      drop
#
#                            status
# 0    review_cross_subject_matches
# 1    review_cross_subject_matches
# 2    review_cross_subject_matches
# 3    review_cross_subject_matches
# 4    review_cross_subject_matches
# ..                            ...
# 823        review_gender_mismatch
# 824                review-unknown
# 825  review_cross_subject_matches
# 826  review_cross_subject_matches
# 827  review_cross_subject_matches
#
# [828 rows x 16 columns]

# %%
manifest.groupby('status').size()
# Out:
# status
# pass                             34
# review-unknown                  153
# review_cross_subject_matches    494
# review_gender_mismatch          147
# dtype: int64

# %%
plate_7962 = pd.read_csv('../../plate103/PL-01007962_v2.csv', usecols=['SUBJECTID', 'ALIASES'])
plate_7962
# Out:
#       SUBJECTID                                            ALIASES
# 0   ST-00031019  NWD222185                                     ...
# 1   ST-00076094  NWD267258|NWD614593                           ...
# 2   ST-00079265  NWD457389|NWD470835|TOE136372                 ...
# 3   ST-01007573  NWD493608|NWD929946                           ...
# 4   ST-00039603  NWD742586|TOE188174                           ...
# ..          ...                                                ...
# 89  ST-00073553  NWD622936|NWD937800|TOE225664                 ...
# 90  ST-00040951  NWD213055|NWD824657|TOE980969                 ...
# 91  ST-00038104  NWD281018                                     ...
# 92  ST-01005316  NWD108023|NWD733322|TOE672588                 ...
# 93  ST-01002480  NWD215983|NWD867190|TOE959331                 ...
#
# [94 rows x 2 columns]

# %%
plate_7365 = pd.read_csv('../../plate103/PL-01007365_v2.csv', usecols=['SUBJECTID', 'ALIASES'])
plate_7365
# Out:
#       SUBJECTID                                            ALIASES
# 0   ST-00035127  NWD570756                                     ...
# 1   ST-00073935  NWD928094                                     ...
# 2   ST-01005121  NWD414052|NWD506449|TOE304395                 ...
# 3   ST-00073296  NWD861833                                     ...
# 4   ST-00036057  NWD794175                                     ...
# ..          ...                                                ...
# 90  ST-00029748  NWD302046                                     ...
# 91  ST-00035989  NWD418461                                     ...
# 92  ST-00033221  NWD861685                                     ...
# 93  ST-00080137  NWD110199|NWD494541|TOE490974                 ...
# 94  ST-00073396  NWD211470|TOE516902                           ...
#
# [95 rows x 2 columns]

# %%
plate_7396 = pd.read_csv('../../plate103/PL-01007396_v2.csv', usecols=['SUBJECTID', 'ALIASES'])
plate_7396
# Out:
#       SUBJECTID                                            ALIASES
# 0   ST-00078386  NWD673092                                     ...
# 1   ST-00029887  NWD349385                                     ...
# 2   ST-00073297  NWD956856                                     ...
# 3   ST-00033483  NWD342091|TOE492562                           ...
# 4   ST-01003037  NWD855394                                     ...
# ..          ...                                                ...
# 91  ST-00079265  NWD457389|NWD470835|TOE136372                 ...
# 92  ST-00039640  NWD856186                                     ...
# 93  ST-00007805  NWD396919                                     ...
# 94  ST-00075956  NWD191773|NWD912312|TOE483764                 ...
# 95  ST-00007435  NWD375367|NWD593699|TOE171917                 ...
#
# [96 rows x 2 columns]

# %%
all_plates = pd.concat([plate_7365, plate_7396, plate_7962]).drop_duplicates()
all_plates
# Out:
#       SUBJECTID                                            ALIASES
# 0   ST-00035127  NWD570756                                     ...
# 1   ST-00073935  NWD928094                                     ...
# 2   ST-01005121  NWD414052|NWD506449|TOE304395                 ...
# 3   ST-00073296  NWD861833                                     ...
# 4   ST-00036057  NWD794175                                     ...
# ..          ...                                                ...
# 84  ST-00007514  NWD680561|NWD849216|TOE621609                 ...
# 85  ST-00075563  NWD933267                                     ...
# 86  ST-00037131  NWD531832|TOE375770                           ...
# 87  ST-00079596  NWD301250|NWD596518                           ...
# 91  ST-00038104  NWD281018                                     ...
#
# [261 rows x 2 columns]

# %%
grouped = manifest[['S_SUBJECTID', 'status']].groupby('S_SUBJECTID')['status'].transform(lambda x: ';'.join(list(set(x))))
grouped
# Out:
# 0      review_cross_subject_matches
# 1      review_cross_subject_matches
# 2      review_cross_subject_matches
# 3      review_cross_subject_matches
# 4      review_cross_subject_matches
#                    ...
# 823          review_gender_mismatch
# 824                  review-unknown
# 825    review_cross_subject_matches
# 826    review_cross_subject_matches
# 827    review_cross_subject_matches
# Name: status, Length: 828, dtype: object

# %%
multiomics_results = manifest[['S_SUBJECTID', 'SampleAlias', 'flags']]
# multiomics_results['ALIASES'] = multiomics_results.groupby('S_SUBJECTID')['SampleAlias'].transform(lambda x: '|'.join(list(set(x))))
multiomics_results
# Out:
#      S_SUBJECTID SampleAlias  \
# 0    ST-00075884   NWD100991
# 1    ST-00075884   NWD866399
# 2    ST-00037405   NWD101684
# 3    ST-00037405   NWD683946
# 4    ST-01005316   NWD108023
# ..           ...         ...
# 823  ST-01001800   TOE867099
# 824  ST-00038470   TOE660427
# 825  ST-00037258   TOE315472
# 826  ST-00037258   TOE881059
# 827  ST-00029860   TOE859130
#
#                                                  flags
# 0    gender_mismatch;observed_gender_indeterminate;...
# 1                                                  NaN
# 2    gender_mismatch;cross_subject_match;unexpected...
# 3        gender_mismatch;observed_gender_indeterminate
# 4    gender_mismatch;cross_subject_match;unexpected...
# ..                                                 ...
# 823                                                NaN
# 824                            observed_gender_missing
# 825    observed_gender_missing;unexpected_geno_nomatch
# 826  observed_gender_missing;cross_subject_match;un...
# 827  observed_gender_missing;cross_subject_match;un...
#
# [828 rows x 3 columns]

# %%
merged = all_plates.merge(multiomics_results, left_on='SUBJECTID', right_on='S_SUBJECTID', how='left')
merged = merged.drop(columns=['S_SUBJECTID'])
merged
# Out:
#        SUBJECTID                                            ALIASES  \
# 0    ST-00035127  NWD570756                                     ...
# 1    ST-00035127  NWD570756                                     ...
# 2    ST-00035127  NWD570756                                     ...
# 3    ST-00035127  NWD570756                                     ...
# 4    ST-00073935  NWD928094                                     ...
# ..           ...                                                ...
# 958  ST-00079596  NWD301250|NWD596518                           ...
# 959  ST-00079596  NWD301250|NWD596518                           ...
# 960  ST-00038104  NWD281018                                     ...
# 961  ST-00038104  NWD281018                                     ...
# 962  ST-00038104  NWD281018                                     ...
#
#     SampleAlias                                              flags
# 0     NWD570756  gender_mismatch;observed_gender_indeterminate;...
# 1        17846T       ;cross_subject_match;unexpected_geno_nomatch
# 2     TOE531047  observed_gender_missing;cross_subject_match;un...
# 3     TOE219717  observed_gender_missing;cross_subject_match;un...
# 4     NWD473599                                                NaN
# ..          ...                                                ...
# 958   TOE789753  observed_gender_missing;cross_subject_match;un...
# 959   TOE736301  observed_gender_missing;cross_subject_match;un...
# 960   NWD281018      gender_mismatch;observed_gender_indeterminate
# 961   NWD799764  gender_mismatch;cross_subject_match;unexpected...
# 962      14159L       ;cross_subject_match;unexpected_geno_nomatch
#
# [963 rows x 4 columns]

# %%
subjects = merged['SUBJECTID'].unique()
for subject in subjects:
    all_rows = merged[merged['SUBJECTID'] == subject]
    # print(all_rows['flags'])
    for row in all_rows.iterrows():
        print(f'{subject}, {row[1]["ALIASES"]}, {row[1]["flags"]}')
    print('OK')
# Out:
# ST-00035127, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00035127, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00035127, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00035127, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00073935, row[1]["ALIASES"], nan
# ST-00073935, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00073935, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00073935, row[1]["ALIASES"], nan
# ST-00073935, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00073935, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-01005121, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-01005121, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-01005121, row[1]["ALIASES"], ;unexpected_geno_nomatch
# ST-01005121, row[1]["ALIASES"], observed_gender_missing;unexpected_geno_nomatch
# ST-01005121, row[1]["ALIASES"], observed_gender_missing;unexpected_geno_nomatch
# ST-01005121, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-01005121, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-01005121, row[1]["ALIASES"], ;unexpected_geno_nomatch
# ST-01005121, row[1]["ALIASES"], observed_gender_missing;unexpected_geno_nomatch
# ST-01005121, row[1]["ALIASES"], observed_gender_missing;unexpected_geno_nomatch
# OK
# ST-00073296, row[1]["ALIASES"], nan
# ST-00073296, row[1]["ALIASES"], nan
# ST-00073296, row[1]["ALIASES"], observed_gender_missing
# ST-00073296, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00036057, row[1]["ALIASES"], nan
# ST-00036057, row[1]["ALIASES"], nan
# OK
# ST-00035951, row[1]["ALIASES"], nan
# ST-00035951, row[1]["ALIASES"], nan
# ST-00035951, row[1]["ALIASES"], observed_gender_missing
# ST-00035951, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00029807, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00029807, row[1]["ALIASES"], nan
# ST-00029807, row[1]["ALIASES"], nan
# OK
# ST-00036209, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00036209, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00036209, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00036209, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00036209, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00036209, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00036209, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00036209, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00036209, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00036209, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00033884, row[1]["ALIASES"], nan
# ST-00033884, row[1]["ALIASES"], nan
# OK
# ST-00036649, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00036649, row[1]["ALIASES"], nan
# ST-00036649, row[1]["ALIASES"], observed_gender_missing
# ST-00036649, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00038104, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00038104, row[1]["ALIASES"], gender_mismatch;cross_subject_match;unexpected_geno_nomatch
# ST-00038104, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00038104, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00038104, row[1]["ALIASES"], gender_mismatch;cross_subject_match;unexpected_geno_nomatch
# ST-00038104, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00073475, row[1]["ALIASES"], gender_mismatch;cross_subject_match;unexpected_geno_nomatch
# ST-00073475, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00073475, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00073475, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00034174, row[1]["ALIASES"], nan
# ST-00034174, row[1]["ALIASES"], nan
# ST-00034174, row[1]["ALIASES"], observed_gender_missing
# ST-00034174, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00079596, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00079596, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00079596, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00079596, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00079596, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00079596, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00079596, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00079596, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00079596, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00079596, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00079596, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00079596, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-01001800, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-01001800, row[1]["ALIASES"], nan
# ST-01001800, row[1]["ALIASES"], nan
# OK
# ST-00073683, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00073683, row[1]["ALIASES"], nan
# ST-00073683, row[1]["ALIASES"], nan
# ST-00073683, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00030967, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00030967, row[1]["ALIASES"], nan
# ST-00030967, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00035663, row[1]["ALIASES"], nan
# ST-00035663, row[1]["ALIASES"], nan
# ST-00035663, row[1]["ALIASES"], observed_gender_missing
# ST-00035663, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00034611, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00034611, row[1]["ALIASES"], nan
# ST-00034611, row[1]["ALIASES"], observed_gender_missing
# ST-00034611, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00037049, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00037049, row[1]["ALIASES"], nan
# OK
# ST-00037005, row[1]["ALIASES"], nan
# ST-00037005, row[1]["ALIASES"], nan
# ST-00037005, row[1]["ALIASES"], nan
# ST-00037005, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00038451, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00038451, row[1]["ALIASES"], ;cross_subject_match
# ST-00038451, row[1]["ALIASES"], observed_gender_missing;cross_subject_match
# ST-00038451, row[1]["ALIASES"], observed_gender_missing;cross_subject_match
# OK
# ST-00079595, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00079595, row[1]["ALIASES"], nan
# ST-00079595, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00079595, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00079595, row[1]["ALIASES"], nan
# ST-00079595, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00080239, row[1]["ALIASES"], nan
# ST-00080239, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00080239, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00080239, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00080239, row[1]["ALIASES"], nan
# ST-00080239, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00080239, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00080239, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00029708, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00029708, row[1]["ALIASES"], nan
# ST-00029708, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00073522, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00073522, row[1]["ALIASES"], nan
# ST-00073522, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00073522, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00073522, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00073522, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00073522, row[1]["ALIASES"], nan
# ST-00073522, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00073522, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00073522, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-01005071, row[1]["ALIASES"], nan
# ST-01005071, row[1]["ALIASES"], nan
# ST-01005071, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-01000539, row[1]["ALIASES"], nan
# ST-01000539, row[1]["ALIASES"], nan
# ST-01000539, row[1]["ALIASES"], observed_gender_missing
# ST-01000539, row[1]["ALIASES"], nan
# OK
# ST-00030229, row[1]["ALIASES"], nan
# ST-00030229, row[1]["ALIASES"], nan
# OK
# ST-00034707, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00034707, row[1]["ALIASES"], nan
# OK
# ST-00029860, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00029860, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00029860, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00035056, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00035056, row[1]["ALIASES"], nan
# ST-00035056, row[1]["ALIASES"], observed_gender_missing
# ST-00035056, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00041085, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00041085, row[1]["ALIASES"], nan
# ST-00041085, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00073476, row[1]["ALIASES"], nan
# ST-00073476, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00073476, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00073476, row[1]["ALIASES"], nan
# ST-00073476, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00073476, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00039763, row[1]["ALIASES"], gender_mismatch;cross_subject_match;unexpected_geno_nomatch
# ST-00039763, row[1]["ALIASES"], nan
# ST-00039763, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00039763, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00039763, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00039763, row[1]["ALIASES"], gender_mismatch;cross_subject_match;unexpected_geno_nomatch
# ST-00039763, row[1]["ALIASES"], nan
# ST-00039763, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00039763, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00039763, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00073553, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00073553, row[1]["ALIASES"], nan
# ST-00073553, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00073553, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00073553, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00037258, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;unexpected_geno_nomatch
# ST-00037258, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00037258, row[1]["ALIASES"], ;unexpected_geno_nomatch
# ST-00037258, row[1]["ALIASES"], observed_gender_missing;unexpected_geno_nomatch
# ST-00037258, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00037258, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;unexpected_geno_nomatch
# ST-00037258, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00037258, row[1]["ALIASES"], ;unexpected_geno_nomatch
# ST-00037258, row[1]["ALIASES"], observed_gender_missing;unexpected_geno_nomatch
# ST-00037258, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00037131, row[1]["ALIASES"], gender_mismatch;cross_subject_match;unexpected_geno_nomatch
# ST-00037131, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00037131, row[1]["ALIASES"], ;unexpected_geno_nomatch
# ST-00037131, row[1]["ALIASES"], observed_gender_missing;unexpected_geno_nomatch
# ST-00037131, row[1]["ALIASES"], gender_mismatch;cross_subject_match;unexpected_geno_nomatch
# ST-00037131, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00037131, row[1]["ALIASES"], ;unexpected_geno_nomatch
# ST-00037131, row[1]["ALIASES"], observed_gender_missing;unexpected_geno_nomatch
# OK
# ST-00080609, row[1]["ALIASES"], nan
# ST-00080609, row[1]["ALIASES"], nan
# ST-00080609, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00037954, row[1]["ALIASES"], nan
# ST-00037954, row[1]["ALIASES"], nan
# OK
# ST-00033989, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00033989, row[1]["ALIASES"], nan
# ST-00033989, row[1]["ALIASES"], observed_gender_missing
# ST-00033989, row[1]["ALIASES"], nan
# OK
# ST-00033042, row[1]["ALIASES"], nan
# ST-00033042, row[1]["ALIASES"], nan
# ST-00033042, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00034518, row[1]["ALIASES"], gender_mismatch;cross_subject_match;unexpected_geno_nomatch
# ST-00034518, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00034518, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00032144, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00032144, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00032144, row[1]["ALIASES"], nan
# OK
# ST-00034177, row[1]["ALIASES"], nan
# ST-00034177, row[1]["ALIASES"], nan
# OK
# ST-00031913, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00031913, row[1]["ALIASES"], nan
# ST-00031913, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00031913, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00031913, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00031913, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00031913, row[1]["ALIASES"], nan
# ST-00031913, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00031913, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00031913, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00034679, row[1]["ALIASES"], gender_mismatch;cross_subject_match;unexpected_geno_nomatch
# ST-00034679, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00034679, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00034679, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00034679, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00073452, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00073452, row[1]["ALIASES"], gender_mismatch;cross_subject_match;unexpected_geno_nomatch
# ST-00073452, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00038700, row[1]["ALIASES"], nan
# ST-00038700, row[1]["ALIASES"], nan
# ST-00038700, row[1]["ALIASES"], nan
# ST-00038700, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00073394, row[1]["ALIASES"], gender_mismatch;cross_subject_match;unexpected_geno_nomatch
# ST-00073394, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00073394, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00080574, row[1]["ALIASES"], nan
# ST-00080574, row[1]["ALIASES"], nan
# ST-00080574, row[1]["ALIASES"], observed_gender_missing
# ST-00080574, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00042779, row[1]["ALIASES"], nan
# ST-00042779, row[1]["ALIASES"], nan
# ST-00042779, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00039888, row[1]["ALIASES"], nan
# ST-00039888, row[1]["ALIASES"], nan
# ST-00039888, row[1]["ALIASES"], observed_gender_missing
# ST-00039888, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-01005275, row[1]["ALIASES"], nan
# ST-01005275, row[1]["ALIASES"], nan
# ST-01005275, row[1]["ALIASES"], observed_gender_missing
# ST-01005275, row[1]["ALIASES"], observed_gender_missing
# ST-01005275, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00030642, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00030642, row[1]["ALIASES"], nan
# OK
# ST-00039390, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00039390, row[1]["ALIASES"], nan
# ST-00039390, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00040620, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00040620, row[1]["ALIASES"], nan
# OK
# ST-00037405, row[1]["ALIASES"], gender_mismatch;cross_subject_match;unexpected_geno_nomatch
# ST-00037405, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00037405, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00037405, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00037405, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00037405, row[1]["ALIASES"], gender_mismatch;cross_subject_match;unexpected_geno_nomatch
# ST-00037405, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00037405, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00037405, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00037405, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00034294, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00034294, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00034294, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00034294, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00034294, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00034294, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00073942, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00073942, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00073942, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00073942, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00073942, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00035273, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00035273, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00035273, row[1]["ALIASES"], nan
# OK
# ST-00073320, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00073320, row[1]["ALIASES"], nan
# ST-00073320, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00073320, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00073320, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00073320, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00073320, row[1]["ALIASES"], nan
# ST-00073320, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00073320, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00073320, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00077231, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00077231, row[1]["ALIASES"], nan
# ST-00077231, row[1]["ALIASES"], nan
# ST-00077231, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00032412, row[1]["ALIASES"], nan
# ST-00032412, row[1]["ALIASES"], nan
# ST-00032412, row[1]["ALIASES"], observed_gender_missing
# ST-00032412, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00080453, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00080453, row[1]["ALIASES"], nan
# ST-00080453, row[1]["ALIASES"], observed_gender_missing
# ST-00080453, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-01001722, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-01001722, row[1]["ALIASES"], nan
# ST-01001722, row[1]["ALIASES"], nan
# OK
# ST-00042131, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00042131, row[1]["ALIASES"], nan
# ST-00042131, row[1]["ALIASES"], observed_gender_missing
# ST-00042131, row[1]["ALIASES"], nan
# OK
# ST-00036420, row[1]["ALIASES"], nan
# ST-00036420, row[1]["ALIASES"], nan
# ST-00036420, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00080033, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00080033, row[1]["ALIASES"], nan
# OK
# ST-00040951, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00040951, row[1]["ALIASES"], nan
# ST-00040951, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00040951, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00040951, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00036056, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00036056, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00036056, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00036056, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00036056, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00030576, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00030576, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00030576, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00040738, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match
# ST-00040738, row[1]["ALIASES"], nan
# ST-00040738, row[1]["ALIASES"], observed_gender_missing;cross_subject_match
# OK
# ST-00073520, row[1]["ALIASES"], gender_mismatch;cross_subject_match;unexpected_geno_nomatch
# ST-00073520, row[1]["ALIASES"], nan
# ST-00073520, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00073520, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00073520, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00073520, row[1]["ALIASES"], gender_mismatch;cross_subject_match;unexpected_geno_nomatch
# ST-00073520, row[1]["ALIASES"], nan
# ST-00073520, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00073520, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00073520, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00079712, row[1]["ALIASES"], nan
# ST-00079712, row[1]["ALIASES"], nan
# OK
# ST-00033290, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00033290, row[1]["ALIASES"], nan
# ST-00033290, row[1]["ALIASES"], nan
# OK
# ST-00033671, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00033671, row[1]["ALIASES"], nan
# ST-00033671, row[1]["ALIASES"], nan
# ST-00033671, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00034059, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00034059, row[1]["ALIASES"], nan
# ST-00034059, row[1]["ALIASES"], observed_gender_missing
# ST-00034059, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00033264, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00033264, row[1]["ALIASES"], nan
# ST-00033264, row[1]["ALIASES"], observed_gender_missing
# ST-00033264, row[1]["ALIASES"], nan
# OK
# ST-00036593, row[1]["ALIASES"], nan
# ST-00036593, row[1]["ALIASES"], nan
# ST-00036593, row[1]["ALIASES"], observed_gender_missing
# ST-00036593, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00032137, row[1]["ALIASES"], nan
# ST-00032137, row[1]["ALIASES"], nan
# ST-00032137, row[1]["ALIASES"], observed_gender_missing
# ST-00032137, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00032745, row[1]["ALIASES"], gender_mismatch;cross_subject_match;unexpected_geno_nomatch
# ST-00032745, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00032745, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-01002678, row[1]["ALIASES"], nan
# ST-01002678, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-01002678, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-01002678, row[1]["ALIASES"], nan
# ST-01002678, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-01002678, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00035157, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00035157, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00035157, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00035157, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00035157, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00035157, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00035157, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00035157, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00038013, row[1]["ALIASES"], gender_mismatch;cross_subject_match;unexpected_geno_nomatch
# ST-00038013, row[1]["ALIASES"], ;unexpected_geno_nomatch
# ST-00038013, row[1]["ALIASES"], observed_gender_missing;unexpected_geno_nomatch
# OK
# ST-01005301, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-01005301, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-01005301, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-01005301, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-01005301, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00033447, row[1]["ALIASES"], nan
# ST-00033447, row[1]["ALIASES"], nan
# ST-00033447, row[1]["ALIASES"], observed_gender_missing
# ST-00033447, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00080458, row[1]["ALIASES"], nan
# ST-00080458, row[1]["ALIASES"], nan
# ST-00080458, row[1]["ALIASES"], observed_gender_missing
# ST-00080458, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00040564, row[1]["ALIASES"], gender_mismatch;cross_subject_match;unexpected_geno_nomatch
# ST-00040564, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00040564, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00033463, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00033463, row[1]["ALIASES"], nan
# ST-00033463, row[1]["ALIASES"], observed_gender_missing
# ST-00033463, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00029748, row[1]["ALIASES"], nan
# ST-00029748, row[1]["ALIASES"], nan
# ST-00029748, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00035989, row[1]["ALIASES"], nan
# ST-00035989, row[1]["ALIASES"], nan
# ST-00035989, row[1]["ALIASES"], nan
# ST-00035989, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00033221, row[1]["ALIASES"], nan
# ST-00033221, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00033221, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00033221, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00033221, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00033221, row[1]["ALIASES"], nan
# ST-00033221, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00033221, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00033221, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00033221, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00080137, row[1]["ALIASES"], nan
# ST-00080137, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00080137, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00080137, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00073396, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00073396, row[1]["ALIASES"], nan
# ST-00073396, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00073396, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00073396, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00073396, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00073396, row[1]["ALIASES"], nan
# ST-00073396, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00073396, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00073396, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00078386, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00078386, row[1]["ALIASES"], nan
# OK
# ST-00029887, row[1]["ALIASES"], nan
# ST-00029887, row[1]["ALIASES"], nan
# OK
# ST-00073297, row[1]["ALIASES"], nan
# ST-00073297, row[1]["ALIASES"], nan
# OK
# ST-00033483, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00033483, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-01003037, row[1]["ALIASES"], nan
# ST-01003037, row[1]["ALIASES"], nan
# OK
# ST-01003465, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-01003465, row[1]["ALIASES"], nan
# ST-01003465, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-01002846, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-01002846, row[1]["ALIASES"], ;cross_subject_match
# ST-01002846, row[1]["ALIASES"], observed_gender_missing;cross_subject_match
# OK
# ST-01003073, row[1]["ALIASES"], nan
# ST-01003073, row[1]["ALIASES"], ;cross_subject_match
# OK
# ST-00029524, row[1]["ALIASES"], nan
# ST-00029524, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00029524, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00029524, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00029524, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00029524, row[1]["ALIASES"], nan
# ST-00029524, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00029524, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00029524, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00029524, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00031063, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00031063, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00031063, row[1]["ALIASES"], ;unexpected_geno_nomatch
# ST-00031063, row[1]["ALIASES"], observed_gender_missing;unexpected_geno_nomatch
# ST-00031063, row[1]["ALIASES"], observed_gender_missing;unexpected_geno_nomatch
# OK
# ST-01007168, row[1]["ALIASES"], gender_mismatch;cross_subject_match;unexpected_geno_nomatch
# ST-01007168, row[1]["ALIASES"], nan
# ST-01007168, row[1]["ALIASES"], ;unexpected_geno_nomatch
# OK
# ST-01002480, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-01002480, row[1]["ALIASES"], nan
# ST-01002480, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-01002480, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-01002480, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00007497, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00007497, row[1]["ALIASES"], nan
# ST-00007497, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-01007796, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-01007796, row[1]["ALIASES"], nan
# ST-01007796, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00035792, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;unexpected_geno_nomatch
# ST-00035792, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00035792, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00033883, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00033883, row[1]["ALIASES"], nan
# ST-00033883, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-01003120, row[1]["ALIASES"], nan
# ST-01003120, row[1]["ALIASES"], nan
# ST-01003120, row[1]["ALIASES"], nan
# ST-01003120, row[1]["ALIASES"], nan
# OK
# ST-00077140, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00077140, row[1]["ALIASES"], nan
# ST-00077140, row[1]["ALIASES"], nan
# ST-00077140, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00076454, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00076454, row[1]["ALIASES"], ;cross_subject_match
# ST-00076454, row[1]["ALIASES"], observed_gender_missing;cross_subject_match
# OK
# ST-00078607, row[1]["ALIASES"], observed_gender_missing;cross_subject_match
# OK
# ST-00035495, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00035495, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00035495, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00035495, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00035495, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00035495, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00035495, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00035495, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00007695, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00007695, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00007695, row[1]["ALIASES"], ;unexpected_geno_nomatch
# ST-00007695, row[1]["ALIASES"], observed_gender_missing;unexpected_geno_nomatch
# ST-00007695, row[1]["ALIASES"], observed_gender_missing;unexpected_geno_nomatch
# OK
# ST-00030659, row[1]["ALIASES"], nan
# ST-00030659, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00030659, row[1]["ALIASES"], ;unexpected_geno_nomatch
# ST-00030659, row[1]["ALIASES"], nan
# ST-00030659, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00030659, row[1]["ALIASES"], ;unexpected_geno_nomatch
# OK
# ST-00076094, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00076094, row[1]["ALIASES"], nan
# ST-00076094, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00076094, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00076094, row[1]["ALIASES"], nan
# ST-00076094, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00078696, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00078696, row[1]["ALIASES"], nan
# ST-00078696, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-01007606, row[1]["ALIASES"], nan
# ST-01007606, row[1]["ALIASES"], nan
# ST-01007606, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00030293, row[1]["ALIASES"], nan
# ST-00030293, row[1]["ALIASES"], nan
# ST-00030293, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-01012418, row[1]["ALIASES"], ;cross_subject_match
# OK
# ST-01002558, row[1]["ALIASES"], nan
# ST-01002558, row[1]["ALIASES"], nan
# ST-01002558, row[1]["ALIASES"], observed_gender_missing
# ST-01002558, row[1]["ALIASES"], observed_gender_missing
# ST-01002558, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00074664, row[1]["ALIASES"], nan
# ST-00074664, row[1]["ALIASES"], nan
# ST-00074664, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00075155, row[1]["ALIASES"], ;cross_subject_match
# OK
# ST-01003420, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-01003420, row[1]["ALIASES"], ;cross_subject_match
# OK
# ST-00032392, row[1]["ALIASES"], gender_mismatch;cross_subject_match;unexpected_geno_nomatch
# ST-00032392, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00032392, row[1]["ALIASES"], ;unexpected_geno_nomatch
# OK
# ST-00075884, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00075884, row[1]["ALIASES"], nan
# ST-00075884, row[1]["ALIASES"], ;unexpected_geno_nomatch
# OK
# ST-01002662, row[1]["ALIASES"], nan
# ST-01002662, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-01002662, row[1]["ALIASES"], ;unexpected_geno_nomatch
# OK
# ST-00078131, row[1]["ALIASES"], nan
# ST-00078131, row[1]["ALIASES"], ;cross_subject_match
# ST-00078131, row[1]["ALIASES"], observed_gender_missing;cross_subject_match
# ST-00078131, row[1]["ALIASES"], observed_gender_missing;cross_subject_match
# OK
# ST-00007617, row[1]["ALIASES"], nan
# ST-00007617, row[1]["ALIASES"], nan
# ST-00007617, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00008091, row[1]["ALIASES"], nan
# ST-00008091, row[1]["ALIASES"], nan
# ST-00008091, row[1]["ALIASES"], observed_gender_missing
# ST-00008091, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00035041, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00035041, row[1]["ALIASES"], nan
# ST-00035041, row[1]["ALIASES"], observed_gender_missing
# ST-00035041, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00033612, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00033612, row[1]["ALIASES"], nan
# ST-00033612, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-01003059, row[1]["ALIASES"], nan
# ST-01003059, row[1]["ALIASES"], nan
# ST-01003059, row[1]["ALIASES"], observed_gender_missing
# ST-01003059, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-01002609, row[1]["ALIASES"], ;unexpected_geno_nomatch
# ST-01002609, row[1]["ALIASES"], nan
# ST-01002609, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-01002609, row[1]["ALIASES"], ;unexpected_geno_nomatch
# OK
# ST-00077563, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00077563, row[1]["ALIASES"], nan
# ST-00077563, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00077563, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00077563, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00077563, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00077563, row[1]["ALIASES"], nan
# ST-00077563, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00077563, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00077563, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00075032, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00075032, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00075032, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00075032, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00075032, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00075032, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00036788, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00036788, row[1]["ALIASES"], nan
# ST-00036788, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00036788, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00036788, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00036788, row[1]["ALIASES"], nan
# ST-00036788, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00036788, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00076941, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00076941, row[1]["ALIASES"], nan
# ST-00076941, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00076941, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00076941, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00076941, row[1]["ALIASES"], nan
# ST-00076941, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00076941, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00077987, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00077987, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00077987, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00077987, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00077987, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00077987, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00077987, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00077987, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00077987, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00077987, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00007746, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00007746, row[1]["ALIASES"], nan
# ST-00007746, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00007746, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00007746, row[1]["ALIASES"], nan
# ST-00007746, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-01001373, row[1]["ALIASES"], nan
# ST-01001373, row[1]["ALIASES"], nan
# ST-01001373, row[1]["ALIASES"], observed_gender_missing
# ST-01001373, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00076843, row[1]["ALIASES"], nan
# ST-00076843, row[1]["ALIASES"], nan
# ST-00076843, row[1]["ALIASES"], observed_gender_missing
# ST-00076843, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00038470, row[1]["ALIASES"], nan
# ST-00038470, row[1]["ALIASES"], nan
# ST-00038470, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00037280, row[1]["ALIASES"], nan
# ST-00037280, row[1]["ALIASES"], nan
# ST-00037280, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-01003056, row[1]["ALIASES"], nan
# ST-01003056, row[1]["ALIASES"], nan
# OK
# ST-00074211, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00074211, row[1]["ALIASES"], nan
# ST-00074211, row[1]["ALIASES"], observed_gender_missing
# ST-00074211, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00076238, row[1]["ALIASES"], nan
# ST-00076238, row[1]["ALIASES"], ;cross_subject_match
# ST-00076238, row[1]["ALIASES"], observed_gender_missing;cross_subject_match
# ST-00076238, row[1]["ALIASES"], observed_gender_missing;cross_subject_match
# OK
# ST-00077890, row[1]["ALIASES"], ;cross_subject_match
# OK
# ST-00035162, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00035162, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00035162, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00035162, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00035162, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00075528, row[1]["ALIASES"], nan
# ST-00075528, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00075528, row[1]["ALIASES"], ;unexpected_geno_nomatch
# OK
# ST-01005316, row[1]["ALIASES"], gender_mismatch;cross_subject_match;unexpected_geno_nomatch
# ST-01005316, row[1]["ALIASES"], nan
# ST-01005316, row[1]["ALIASES"], ;unexpected_geno_nomatch
# ST-01005316, row[1]["ALIASES"], ;unexpected_geno_nomatch
# ST-01005316, row[1]["ALIASES"], observed_gender_missing;unexpected_geno_nomatch
# OK
# ST-00077107, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00077107, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00077107, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00077107, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00077107, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00077107, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00077107, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00077107, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00077107, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00077107, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00074722, row[1]["ALIASES"], nan
# ST-00074722, row[1]["ALIASES"], nan
# OK
# ST-00074846, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00074846, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;unexpected_geno_nomatch
# ST-00074846, row[1]["ALIASES"], ;unexpected_geno_nomatch
# ST-00074846, row[1]["ALIASES"], observed_gender_missing;unexpected_geno_nomatch
# ST-00074846, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00074846, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00074846, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;unexpected_geno_nomatch
# ST-00074846, row[1]["ALIASES"], ;unexpected_geno_nomatch
# ...
# OK
# ST-00008063, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00008063, row[1]["ALIASES"], nan
# ST-00008063, row[1]["ALIASES"], observed_gender_missing
# ST-00008063, row[1]["ALIASES"], nan
# ST-00008063, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00078459, row[1]["ALIASES"], nan
# ST-00078459, row[1]["ALIASES"], ;cross_subject_match
# ST-00078459, row[1]["ALIASES"], ;cross_subject_match
# ST-00078459, row[1]["ALIASES"], observed_gender_missing;cross_subject_match
# OK
# ST-00007449, row[1]["ALIASES"], nan
# ST-00007449, row[1]["ALIASES"], ;cross_subject_match
# ST-00007449, row[1]["ALIASES"], ;cross_subject_match
# ST-00007449, row[1]["ALIASES"], observed_gender_missing;cross_subject_match
# OK
# ST-00036962, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00036962, row[1]["ALIASES"], nan
# ST-00036962, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00036962, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00036962, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00036962, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00036962, row[1]["ALIASES"], nan
# ST-00036962, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00036962, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00036962, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-01006828, row[1]["ALIASES"], nan
# ST-01006828, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-01006828, row[1]["ALIASES"], ;unexpected_geno_nomatch
# ST-01006828, row[1]["ALIASES"], observed_gender_missing;unexpected_geno_nomatch
# ST-01006828, row[1]["ALIASES"], observed_gender_missing;unexpected_geno_nomatch
# ST-01006828, row[1]["ALIASES"], nan
# ST-01006828, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-01006828, row[1]["ALIASES"], ;unexpected_geno_nomatch
# ST-01006828, row[1]["ALIASES"], observed_gender_missing;unexpected_geno_nomatch
# ST-01006828, row[1]["ALIASES"], observed_gender_missing;unexpected_geno_nomatch
# OK
# ST-00008251, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00008251, row[1]["ALIASES"], nan
# ST-00008251, row[1]["ALIASES"], ;unexpected_geno_nomatch
# OK
# ST-00007514, row[1]["ALIASES"], nan
# ST-00007514, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00007514, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00007514, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00007514, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00007514, row[1]["ALIASES"], nan
# ST-00007514, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00007514, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00007514, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00007514, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-01003034, row[1]["ALIASES"], nan
# ST-01003034, row[1]["ALIASES"], nan
# ST-01003034, row[1]["ALIASES"], observed_gender_missing
# ST-01003034, row[1]["ALIASES"], nan
# ST-01003034, row[1]["ALIASES"], nan
# OK
# ST-01007244, row[1]["ALIASES"], nan
# ST-01007244, row[1]["ALIASES"], nan
# ST-01007244, row[1]["ALIASES"], observed_gender_missing
# ST-01007244, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00007491, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00007491, row[1]["ALIASES"], nan
# OK
# ST-00034395, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00034395, row[1]["ALIASES"], nan
# ST-00034395, row[1]["ALIASES"], observed_gender_missing
# ST-00034395, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00078946, row[1]["ALIASES"], nan
# ST-00078946, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-01003389, row[1]["ALIASES"], nan
# ST-01003389, row[1]["ALIASES"], nan
# OK
# ST-01002215, row[1]["ALIASES"], nan
# ST-01002215, row[1]["ALIASES"], ;cross_subject_match
# ST-01002215, row[1]["ALIASES"], observed_gender_missing;cross_subject_match
# ST-01002215, row[1]["ALIASES"], observed_gender_missing;cross_subject_match
# OK
# ST-00079265, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00079265, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00079265, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00079265, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00079265, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00079265, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00079265, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00079265, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00039640, row[1]["ALIASES"], nan
# ST-00039640, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00039640, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00039640, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00039640, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00039640, row[1]["ALIASES"], nan
# ST-00039640, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00039640, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00039640, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00039640, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00007805, row[1]["ALIASES"], nan
# ST-00007805, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00007805, row[1]["ALIASES"], ;unexpected_geno_nomatch
# ST-00007805, row[1]["ALIASES"], nan
# ST-00007805, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00007805, row[1]["ALIASES"], ;unexpected_geno_nomatch
# OK
# ST-00075956, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00075956, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00075956, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00075956, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00075956, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00075956, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00075956, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00075956, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00007435, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00007435, row[1]["ALIASES"], gender_mismatch;cross_subject_match;unexpected_geno_nomatch
# ST-00007435, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00007435, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00007435, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00007435, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00007435, row[1]["ALIASES"], gender_mismatch;cross_subject_match;unexpected_geno_nomatch
# ST-00007435, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00007435, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00007435, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00031019, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00031019, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00031019, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-01007573, row[1]["ALIASES"], nan
# ST-01007573, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-01007573, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00039603, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00039603, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00039603, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00039603, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00039603, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00074132, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00074132, row[1]["ALIASES"], nan
# ST-00074132, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00074132, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00074678, row[1]["ALIASES"], nan
# ST-00074678, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00074678, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00074678, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00074678, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00032350, row[1]["ALIASES"], nan
# ST-00032350, row[1]["ALIASES"], gender_mismatch;cross_subject_match;unexpected_geno_nomatch
# ST-00032350, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00032350, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00077576, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00077576, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00077576, row[1]["ALIASES"], ;unexpected_geno_nomatch
# ST-00077576, row[1]["ALIASES"], ;cross_subject_match
# OK
# ST-00076749, row[1]["ALIASES"], gender_mismatch
# ST-00076749, row[1]["ALIASES"], gender_mismatch
# ST-00076749, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00030102, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00030102, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00030102, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-01001405, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-01001405, row[1]["ALIASES"], gender_mismatch;cross_subject_match;unexpected_geno_nomatch
# ST-01001405, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-01001405, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-01001405, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00007731, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00007731, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00007731, row[1]["ALIASES"], ;cross_subject_match
# ST-00007731, row[1]["ALIASES"], observed_gender_missing;cross_subject_match
# ST-00007731, row[1]["ALIASES"], observed_gender_missing;cross_subject_match
# OK
# ST-00033889, row[1]["ALIASES"], gender_mismatch;cross_subject_match;unexpected_geno_nomatch
# ST-00033889, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00033889, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00033889, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00035169, row[1]["ALIASES"], gender_mismatch;cross_subject_match;unexpected_geno_nomatch
# ST-00035169, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00035169, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00035169, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-01005309, row[1]["ALIASES"], gender_mismatch
# ST-01005309, row[1]["ALIASES"], gender_mismatch
# ST-01005309, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00036646, row[1]["ALIASES"], nan
# ST-00036646, row[1]["ALIASES"], nan
# OK
# ST-01005168, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-01005168, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-01005168, row[1]["ALIASES"], ;unexpected_geno_nomatch
# OK
# ST-00035530, row[1]["ALIASES"], gender_mismatch;cross_subject_match;unexpected_geno_nomatch
# ST-00035530, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00035530, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00035530, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00037848, row[1]["ALIASES"], nan
# ST-00037848, row[1]["ALIASES"], nan
# ST-00037848, row[1]["ALIASES"], observed_gender_missing
# ST-00037848, row[1]["ALIASES"], observed_gender_missing
# OK
# ST-00036808, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00036808, row[1]["ALIASES"], gender_mismatch;cross_subject_match;unexpected_geno_nomatch
# ST-00036808, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00036808, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00076175, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00076175, row[1]["ALIASES"], gender_mismatch;cross_subject_match;unexpected_geno_nomatch
# ST-00076175, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-01002495, row[1]["ALIASES"], gender_mismatch;cross_subject_match;unexpected_geno_nomatch
# ST-01002495, row[1]["ALIASES"], nan
# ST-01002495, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-01002495, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-01002495, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00037682, row[1]["ALIASES"], nan
# ST-00037682, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00037682, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00037682, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-01005151, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-01005151, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-01005151, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-00074938, row[1]["ALIASES"], nan
# ST-00074938, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00074938, row[1]["ALIASES"], ;unexpected_geno_nomatch
# OK
# ST-00078709, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match;unexpected_geno_nomatch
# ST-00078709, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate
# ST-00078709, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00078709, row[1]["ALIASES"], observed_gender_missing;cross_subject_match;unexpected_geno_nomatch
# ST-00078709, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# OK
# ST-01020023, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match
# ST-01020023, row[1]["ALIASES"], gender_mismatch;observed_gender_indeterminate;cross_subject_match
# ST-01020023, row[1]["ALIASES"], observed_gender_missing;cross_subject_match
# OK
# ST-00075563, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# ST-00075563, row[1]["ALIASES"], nan
# ST-00075563, row[1]["ALIASES"], ;cross_subject_match;unexpected_geno_nomatch
# OK
