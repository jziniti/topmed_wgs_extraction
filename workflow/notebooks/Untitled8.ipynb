# %%
import os
import pandas as pd
from pathlib import Path

FREEZE_DIR = Path('/proj/regeps/regep00/studies/TopMed/data/dna/whole_genome/TopMed/data/freezes/freeze.10.cdnm')

os.chdir(FREEZE_DIR)

# %%
c_data = pd.read_csv('tmp/GECOPD/c_data.build_sample_groups')

annotated_manifest = pd.read_csv('tmp/GECOPD/ANNOTATED_MANIFEST.build_sample_groups.csv', dtype={'S_SUBJECTID': str})
annotated_manifest['flags'].fillna(value='', inplace=True)
annotated_manifest['action'] = 'keep'   ### Let's be optimistic!
annotated_manifest['status'] = ''
annotated_manifest
# Out:
#                                              SampleLabel S_SAMPLEID_manifest  \
# 0                                              NWD100018                 NaN
# 1                                              NWD100059                 NaN
# 2                                              NWD100095                 NaN
# 3                                              NWD100109                 NaN
# 4                                              NWD100230                 NaN
# ...                                                  ...                 ...
# 37574               S-001644042_accepted_hits.sorted.bam         S-001644042
# 37575               S-001644043_accepted_hits.sorted.bam         S-001644043
# 37576               S-001644044_accepted_hits.sorted.bam         S-001644044
# 37577  S-001648029_CGGCGTGA-GCGCCTGT_L003_accepted_hi...         S-001648029
# 37578  S-001648324_CTCTCGTC-TATAACCT_L002_accepted_hi...         S-001648324
#
# ...

# %%
annotated_manifest['flags'].value_counts()
# Out:
#                                  37127
# observed_gender_missing            297
# gender_mismatch                    116
# observed_gender_indeterminate       30
# expected_gender_unknown              9
# Name: flags, dtype: int64
