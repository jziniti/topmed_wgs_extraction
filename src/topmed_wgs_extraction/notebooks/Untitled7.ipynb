# %%
import os
import pandas as pd

os.chdir('/proj/regeps/regep00/studies/TopMed/data/dna/whole_genome/TopMed/data/freezes/freeze.10.cdnm')

# %%
annotated_manifest = pd.read_csv('multiomics/GECOPD.1/ANNOTATED_MANIFEST.csv')
annotated_manifest
# Out:
# /udd/rejpz/.conda/envs/cdnm-jupyter-python-3.7.6/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (8,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        Unnamed: 0 SampleLabel S_SAMPLEID_manifest SampleAlias SampleTypeCode  \
# 0               0   NWD100018                 NaN   NWD100018              d
# 1               1   NWD100059                 NaN   NWD100059              d
# 2               2   NWD100095                 NaN   NWD100095              d
# 3               3   NWD100109                 NaN   NWD100109              d
# 4               4   NWD100230                 NaN   NWD100230              d
# ...           ...         ...                 ...         ...            ...
# 33578       33578      308234                 NaN      308234              r
# 33579       33579      308236                 NaN      308236              r
# ...

# %%
subject_groups = annotated_manifest[['S_SUBJECTID', 'group_id']].drop_duplicates()
subject_groups
# Out:
#        S_SUBJECTID  group_id
# 0      ST-01000557     21616
# 1      ST-00033813      1530
# 2      ST-00075744      3812
# 3      ST-00078957     11430
# 4      ST-00077474     16185
# ...            ...       ...
# 33578       308234       381
# 33579       308236       382
# 33580       308238       383
# 33581       308240       384
# 33582       308242       385
#
# [23522 rows x 2 columns]

# %%
### Plate 103
plate103_map = pd.read_csv('plate103/PL-01007962_v2.csv')
plate103_map['aliases'] = plate103_map['ALIASES'].str.split('|')
plate103_map
# multi_thumbnailer.graph(list(plate103['group_id']), shape_by='dataset_id', filename='multiomics/GECOPD/images/plate103.html', n_columns=12)
# Out:
#    ROW  COL    SUBJECTID     SAMPLEID  \
# 0    A    1  ST-00031019  S-000559445
# 1    A   10  ST-00076094  S-001151897
# 2    A   11  ST-00079265  S-001151516
# 3    A   12  ST-01007573  S-001594638
# 4    A    2  ST-00039603  S-001723867
# ..  ..  ...          ...          ...
# 89   H    5  ST-00073553  S-001110916
# 90   H    6  ST-00040951  S-000537550
# 91   H    7  ST-00038104  S-000537183
# 92   H    8  ST-01005316  S-001152072
# 93   H    9  ST-01002480  S-001173914
#
#                                               ALIASES  \
# 0   NWD222185                                     ...
# 1   NWD267258|NWD614593                           ...
# 2   NWD457389|NWD470835|TOE136372                 ...
# 3   NWD493608|NWD929946                           ...
# 4   NWD742586|TOE188174                           ...
# ..                                                ...
# 89  NWD622936|NWD937800|TOE225664                 ...
# 90  NWD213055|NWD824657|TOE980969                 ...
# ...

# %%
plate103_map = plate103_map.merge(subject_groups, left_on='SUBJECTID', right_on='S_SUBJECTID')
plate103_map.sort_values(['ROW', 'COL'], axis=0, inplace=True)
plate103_map
# Out:
#    ROW  COL    SUBJECTID     SAMPLEID  \
# 0    A    1  ST-00031019  S-000559445
# 4    A    2  ST-00039603  S-001723867
# 5    A    3  ST-00032745  S-000534453
# 6    A    4  ST-00074132  S-001594692
# 7    A    5  ST-00036962  S-000543875
# ..  ..  ...          ...          ...
# 91   H    7  ST-00038104  S-000537183
# 92   H    8  ST-01005316  S-001152072
# 93   H    9  ST-01002480  S-001173914
# 84   H   10  ST-00007514  S-001116470
# 85   H   11  ST-00075563  S-001593150
#
#                                               ALIASES  \
# 0   NWD222185                                     ...
# 4   NWD742586|TOE188174                           ...
# 5   NWD317221|NWD387270                           ...
# 6   NWD167868|NWD351617                           ...
# 7   NWD740133|TOE225615                           ...
# ..                                                ...
# 91  NWD281018                                     ...
# 92  NWD108023|NWD733322|TOE672588                 ...
# ...
