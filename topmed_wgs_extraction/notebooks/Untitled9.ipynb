# %%
import os
import pandas as pd
from pathlib import Path

# %%
FREEZE10 = '/proj/regeps/regep00/studies/TopMed/data/dna/whole_genome/TopMed/data/freezes/freeze.10.cdnm/'
MANIFEST = 'multiomics/GECOPD/ANNOTATED_MANIFEST.csv'

# %%
os.chdir(FREEZE10)

# %%
manifest = pd.read_csv(MANIFEST)
manifest
# Out:
#        Unnamed: 0  Unnamed: 0.1  \
# 0               0             0
# 1               1             1
# 2               2             2
# 3               3             3
# 4               4             4
# ...           ...           ...
# 37603       37603         37574
# 37604       37604         37575
# 37605       37605         37576
# 37606       37606         37577
# 37607       37607         37578
#
#                                              SampleLabel S_SAMPLEID_manifest  \
# 0                                              NWD100018                 NaN
# 1                                              NWD100059                 NaN
# 2                                              NWD100095                 NaN
# 3                                              NWD100109                 NaN
# 4                                              NWD100230                 NaN
# ...                                                  ...                 ...
# 37603               S-001644042_accepted_hits.sorted.bam         S-001644042
# 37604               S-001644043_accepted_hits.sorted.bam         S-001644043
# 37605               S-001644044_accepted_hits.sorted.bam         S-001644044
# 37606  S-001648029_CGGCGTGA-GCGCCTGT_L003_accepted_hi...         S-001648029
# 37607  S-001648324_CTCTCGTC-TATAACCT_L002_accepted_hi...         S-001648324
#
#                                              SampleAlias SampleTypeCode  \
# 0                                              NWD100018              w
# 1                                              NWD100059              w
# 2                                              NWD100095              w
# 3                                              NWD100109              w
# 4                                              NWD100230              w
# ...                                                  ...            ...
# 37603               S-001644042_accepted_hits.sorted.bam              r
# 37604               S-001644043_accepted_hits.sorted.bam              r
# 37605               S-001644044_accepted_hits.sorted.bam              r
# 37606  S-001648029_CGGCGTGA-GCGCCTGT_L003_accepted_hi...              r
# 37607  S-001648324_CTCTCGTC-TATAACCT_L002_accepted_hi...              r
#
#        dataset_id  is_reference  S_SUBJECTID   S_SAMPLEID  ...  \
# 0               0             0  ST-01000557  S-001174464  ...
# 1               0             0  ST-00033813  S-000554104  ...
# 2               0             0  ST-00075744  S-000964706  ...
# 3               0             0  ST-00078957  S-001558939  ...
# 4               0             0  ST-00077474  S-001557255  ...
# ...           ...           ...          ...          ...  ...
# 37603           4             0  ST-01024867  S-001644042  ...
# 37604           4             0  ST-01024865  S-001644043  ...
# 37605           4             0  ST-01024872  S-001644044  ...
# 37606           4             0  ST-01002733  S-001648029  ...
# 37607           4             0  ST-01007272  S-001648324  ...
#
#       u_legacyfamilyid u_packageid ExpectedGender ObservedGender  \
# 0                  NaN         NaN              M              M
# 1                  NaN         NaN              M              F
# 2                  NaN         NaN              F              F
# 3                  NaN         NaN              F              F
# 4                  NaN         NaN              F              F
# ...                ...         ...            ...            ...
# 37603              NaN         NaN              M            NaN
# 37604              NaN         NaN              M            NaN
# 37605              NaN         NaN              M            NaN
# 37606              NaN         NaN              F              F
# 37607              NaN         NaN              M              M
#
#                                                    flags group_id c_group  \
# 0                               ;unexpected_geno_nomatch     7195       0
# 1      cross_subject_match;gender_mismatch;unexpected...      945       1
# 2                                                    NaN     3389       2
# 3                                                    NaN     6570       3
# 4                                                    NaN     5098       4
# ...                                                  ...      ...     ...
# 37603                            observed_gender_missing    10632    1912
# 37604                            observed_gender_missing    10630    8610
# 37605                            observed_gender_missing    10635    3547
# 37606                                                NaN     8040    1823
# 37607                                                NaN     9886    2617
#
#        action_overridden status    action
# 0                   keep    NaN       NaN
# 1                   keep    NaN  reassign
# 2                   keep    NaN       NaN
# 3                   keep    NaN       NaN
# 4                   keep    NaN       NaN
# ...                  ...    ...       ...
# 37603               keep    NaN       NaN
# 37604               keep    NaN       NaN
# 37605               keep    NaN       NaN
# 37606               keep    NaN       NaN
# 37607               keep    NaN       NaN
#
# [37608 rows x 93 columns]

# %%
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'SampleLabel', 'S_SAMPLEID_manifest',
#        'SampleAlias', 'SampleTypeCode', 'dataset_id', 'is_reference',
#        'S_SUBJECTID', 'S_SAMPLEID', 'S_SUBJECTID_sample', 'S_STUDYID',
#        'ALIASTYPE', 'ALIASID', 's_sampleid', 'sampledesc', 'sampletypeid_x',
#        'batchid', 'samplefamilyid', 'activeflag_x', 's_samplefamilyid',
#        'samplefamilydesc', 'initialpackageid', 'initialdepartmentid',
#        'sstudyid', 'studysiteid', 'collectiondt', 'collectmethodid',
#        'verifiedby', 'verifieddt', 'approvedby', 'approveddt', 'recieveddt',
#        'cocflag', 'restrictionsflag', 'age', 'ageunits', 'restrictclassid',
#        'subjectid', 'externalsubject', 'animal', 'diseaseid', 'tissueid',
#        'metastasisid', 'clinicaldiagid', 'conditionalapprovalreason',
#        'conditionalapprovalflag', 'clinicalevent', 'initialmass',
#        'initialmassunits', 'initialvolume', 'initialvolumeunits',
#        'deviationdesc', 'notes', 'auditsequence', 'tracelogid', 'usersequence',
#        'templateflag', 'createdt', 'createby', 'createtool', 'moddt', 'modby',
#        'modtool', 'participantid', 'participanteventid', 'kittrackitem',
#        'clinicalprotocolid', 'clinicalprotocolversionid',
#        'clinicalprotocolrevision', 'eventdefid', 'activeflag_y',
#        'sampletypeid_y', 'specimendefid', 'u_collectionid', 'u_visitname',
#        'u_timepointname', 'u_initsampletypeid', 'u_inittreatmenttypeid',
#        'u_initcontainertypeid', 'u_initenvironmentid', 'u_specimentypeid',
#        'u_collectiontypid', 'u_legacyfamilyid', 'u_packageid',
#        'ExpectedGender', 'ObservedGender', 'flags', 'group_id', 'c_group',
#        'action_overridden', 'status', 'action'],
#       dtype='object')
